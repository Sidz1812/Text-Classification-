# %%
# !pip install simpletransformers

# %%
import pandas as pd
from sklearn import preprocessing
from simpletransformers.model import TransformerModel
from sklearn.metrics import f1_score, accuracy_score
import csv

import os
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

# %%
''''
with open ('train_synthetic_real.txt', 'r') as in_file:
  stripped = (line.strip() for line in in_file)
  lines = (line.split("\t") for line in stripped if line)
  with open('dialouge.csv', 'w') as out_file:
    writer = csv.writer(out_file)
    #writer.writerow(('Label', 'Text'))
    writer.writerows(lines)
    '''
# Out:
# '\'\nwith open (\'train_synthetic_real.txt\', \'r\') as in_file:\n  stripped = (line.strip() for line in in_file)\n  lines = (line.split("\t") for line in stripped if line)\n  with open(\'dialouge.csv\', \'w\') as out_file:\n    writer = csv.writer(out_file)\n    #writer.writerow((\'Label\', \'Text\'))\n    writer.writerows(lines)\n    '

# %% [markdown]
# # Preprocessing

# %%
with open ('dialogue_dataset.txt', 'r') as in_file:
  stripped = (line.strip() for line in in_file)
  lines = (line.split("\t") for line in stripped if line)
  with open('dialouge.csv', 'w') as out_file:
    writer = csv.writer(out_file)
    #writer.writerow(('Label', 'Text'))
    writer.writerows(lines)

# %%
dataset = pd.read_csv('dialouge.csv', header= None)

# %%
dataset.iloc[:,0]
# Out:
# 0         __label__fashion
# 1         __label__fashion
# 2         __label__fashion
# 3         __label__fashion
# 4         __label__fashion
#                 ...
# 404751      __label__movie
# 404752      __label__movie
# 404753      __label__movie
# 404754      __label__movie
# 404755      __label__movie
# Name: 0, Length: 404756, dtype: object

# %%
dataset[["Label"]] = dataset.iloc[:,0]

# %%
dataset[["Text"]] = dataset.iloc[:,1]

# %%
dataset
# Out:
#                        0  ...                                       Text
# 0       __label__fashion  ...             no what do you have on fashion
# 1       __label__fashion  ...             no what do you have on fashion
# 2       __label__fashion  ...                no let's chat about fashion
# 3       __label__fashion  ...                no let's chat about fashion
# 4       __label__fashion  ...            no i want to talk about fashion
# ...                  ...  ...                                        ...
# 404751    __label__movie  ...                   how about next goal wins
# 404752    __label__movie  ...   let me know about films like life itself
# 404753    __label__movie  ...         what about who framed roger rabbit
# 404754    __label__movie  ...                               oliver twist
# 404755    __label__movie  ...  tell me about disneynature monkey kingdom
#
# [404756 rows x 4 columns]

# %%
dataset.Label.value_counts()
# Out:
# __label__movie           166708
# __label__news             65229
# __label__chitchat         48639
# __label__music            35036
# __label__tech             23167
# __label__sports           21647
# __label__other            18285
# __label__attraction       10386
# __label__literature        4592
# __label__food              3591
# __label__pets_animals      2384
# __label__celebrities       2304
# __label__fashion            908
# __label__weather            692
# __label__joke               691
# __label__games              265
# __label__fitness            232
# Name: Label, dtype: int64

# %%
dataset = dataset.drop(dataset.iloc[:,0:2], axis=1)

# %%
dataset
# Out:
#                    Label                                       Text
# 0       __label__fashion             no what do you have on fashion
# 1       __label__fashion             no what do you have on fashion
# 2       __label__fashion                no let's chat about fashion
# 3       __label__fashion                no let's chat about fashion
# 4       __label__fashion            no i want to talk about fashion
# ...                  ...                                        ...
# 404751    __label__movie                   how about next goal wins
# 404752    __label__movie   let me know about films like life itself
# 404753    __label__movie         what about who framed roger rabbit
# 404754    __label__movie                               oliver twist
# 404755    __label__movie  tell me about disneynature monkey kingdom
#
# [404756 rows x 2 columns]

# %%
le = preprocessing.LabelEncoder()
le.fit(dataset["Label"])
# Out:
# LabelEncoder()

# %%
dataset['Label'] = le.transform(dataset["Label"])

# %%
dataset
# Out:
#         Label                                       Text
# 0           3             no what do you have on fashion
# 1           3             no what do you have on fashion
# 2           3                no let's chat about fashion
# 3           3                no let's chat about fashion
# 4           3            no i want to talk about fashion
# ...       ...                                        ...
# 404751      9                   how about next goal wins
# 404752      9   let me know about films like life itself
# 404753      9         what about who framed roger rabbit
# 404754      9                               oliver twist
# 404755      9  tell me about disneynature monkey kingdom
#
# [404756 rows x 2 columns]

# %%
df = dataset[["Text", "Label"]]

# %%
df.Label.value_counts()
# Out:
# 9     166708
# 11     65229
# 2      48639
# 10     35036
# 15     23167
# 14     21647
# 12     18285
# 0      10386
# 8       4592
# 5       3591
# 13      2384
# 1       2304
# 3        908
# 16       692
# 7        691
# 6        265
# 4        232
# Name: Label, dtype: int64

# %%
count_class_9, count_class_11, count_class_2, count_class_10,count_class_15,count_class_14,count_class_12, count_class_0, count_class_8, count_class_5, count_class_13, count_class_1, count_class_3, count_class_16, count_class_7, count_class_6, count_class_4 =  df.Label.value_counts()

# %%
df_class_0 = df[df['Label'] == 0]
df_class_1 = df[df['Label'] == 1]
df_class_2 = df[df['Label'] == 2]
df_class_3 = df[df['Label'] == 3]
df_class_4 = df[df['Label'] == 4]
df_class_5 = df[df['Label'] == 5]
df_class_6 = df[df['Label'] == 6]
df_class_7 = df[df['Label'] == 7]
df_class_8 = df[df['Label'] == 8]
df_class_9 = df[df['Label'] == 9]
df_class_10 = df[df['Label'] == 10]
df_class_11 = df[df['Label'] == 11]
df_class_12 = df[df['Label'] == 12]
df_class_13 = df[df['Label'] == 13]
df_class_14 = df[df['Label'] == 14]
df_class_15 = df[df['Label'] == 15]
df_class_16 = df[df['Label'] == 16]

# %%
df_class_0_1 = df_class_0.sample(4000)
df_class_1_1 = df_class_1.sample(4000, replace= True)
df_class_2_1 = df_class_2.sample(4000)
df_class_3_1 = df_class_3.sample(4000, replace= True)
df_class_4_1 = df_class_4.sample(4000, replace= True)
df_class_5_1 = df_class_5.sample(4000, replace= True)
df_class_6_1 = df_class_6.sample(4000, replace= True)
df_class_7_1 = df_class_7.sample(4000, replace= True)
df_class_8_1 = df_class_8.sample(4000)
df_class_9_1 = df_class_9.sample(4000)
df_class_10_1 = df_class_10.sample(4000)
df_class_11_1 = df_class_11.sample(4000)
df_class_12_1 = df_class_12.sample(4000, replace= True)
df_class_13_1 = df_class_13.sample(4000, replace= True)
df_class_14_1 = df_class_14.sample(4000)
df_class_15_1 = df_class_15.sample(4000)
df_class_16_1 = df_class_16.sample(4000, replace= True)

# %%
df_test_under = pd.concat([df_class_0_1, df_class_1_1, df_class_2_1, df_class_3_1, df_class_4_1, df_class_5_1, df_class_6_1, df_class_7_1, df_class_8_1, df_class_9_1, df_class_10_1, df_class_11_1, df_class_12_1, df_class_13_1, df_class_14_1, df_class_15_1, df_class_16_1], axis=0)

# %%
df_test_under
# Out:
#                                             Text  Label
# 105365                                    dothan      0
# 99841                   let's talk about lubbock      0
# 100947              let's talk about miami beach      0
# 102170                 tell me about new zealand      0
# 97952          what are dairy queen in stockholm      0
# ...                                          ...    ...
# 1282                            it's a foggy day     16
# 1204    weather information in stockholm austria     16
# 1280                            it's a misty day     16
# 1514                                 subtropical     16
# 1557                                  turbulence     16
#
# [68000 rows x 2 columns]

# %%
df = df_test_under.reindex()

# %%
df = df.reset_index()
del df['index']

# %%
df
# Out:
#                                            Text  Label
# 0                                        dothan      0
# 1                      let's talk about lubbock      0
# 2                  let's talk about miami beach      0
# 3                     tell me about new zealand      0
# 4             what are dairy queen in stockholm      0
# ...                                         ...    ...
# 67995                          it's a foggy day     16
# 67996  weather information in stockholm austria     16
# 67997                          it's a misty day     16
# 67998                               subtropical     16
# 67999                                turbulence     16
#
# [68000 rows x 2 columns]

# %%
df = df.sample(frac=1).reset_index(drop=True)

# %%
df
# Out:
#                                               Text  Label
# 0                                            largo      0
# 1                                      liv ullmann      9
# 2                    weather information in berlin     16
# 3                            tomboy fashion styles      3
# 4                           just a new joke thanks      7
# ...                                            ...    ...
# 67995  i wanna talk about foods like italian bread      5
# 67996         something about meal like sloppy joe      5
# 67997                                    megalodon     13
# 67998                        fashion alexa fashion      3
# 67999                              c lewis authors      8
#
# [68000 rows x 2 columns]

# %%
train_df = df.iloc[0:60000, :] 
test_df = df.iloc[60000:68000, :]

# %%
train_df
# Out:
#                                                 Text  Label
# 0                                              largo      0
# 1                                        liv ullmann      9
# 2                      weather information in berlin     16
# 3                              tomboy fashion styles      3
# 4                             just a new joke thanks      7
# ...                                              ...    ...
# 59995                                  eliot l engel     11
# 59996                        do you know about nacho      5
# 59997            what are popular breed of crocodile     13
# 59998  festive story about ksjkuew sjdhsd lsl please      7
# 59999                                          l and     11
#
# [60000 rows x 2 columns]

# %%
test_df
# Out:
#                                                     Text  Label
# 60000  just chat about institutions like ngl energy p...     15
# 60001                   tell me about buffalo wild wings      0
# 60002                                okay we re done man      2
# 60003                       i gonna talk about dele alli     11
# 60004                                     kenneth graham     11
# ...                                                  ...    ...
# 67995        i wanna talk about foods like italian bread      5
# 67996               something about meal like sloppy joe      5
# 67997                                          megalodon     13
# 67998                              fashion alexa fashion      3
# 67999                                    c lewis authors      8
#
# [8000 rows x 2 columns]

# %% [markdown]
# # RoBERTa

# %% [markdown]
# **Fine Tuning on Pretrainined Model**

# %%
model = TransformerModel('roberta', 'roberta-large', num_labels=17, use_cuda=True,
args={'learning_rate':1e-5, 'num_train_epochs': 2, 
      'train_batch_size': 32, 'eval_batch_size': 32,               
      'reprocess_input_data': True, 'overwrite_output_dir': True})
# Out:
# Some weights of the model checkpoint at roberta-large were not used when initializing RobertaForSequenceClassification: ['lm_head.dense.weight', 'roberta.pooler.dense.bias', 'roberta.pooler.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %% [markdown]
# **Training**

# %%
model.train_model(train_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:586: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# ...
# Running Epoch 1 of 2:   0%|          | 0/1875 [00:00<?, ?it/s]
# (3750, 0.3524978413303693)

# %% [markdown]
# **Testing**

# %%
def f1_multiclass(labels, preds):
      return f1_score(labels, preds, average='micro')

result, model_outputs, wrong_predictions = model.eval_model(test_df, f1=f1_multiclass, acc=accuracy_score)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# ...
# Running Evaluation:   0%|          | 0/250 [00:00<?, ?it/s]

# %% [markdown]
# **Accuracy / F1 - Score**

# %%
result
# Out:
# {'mcc': 0.9489475149818775,
#  'f1': 0.9519,
#  'acc': 0.9519,
#  'eval_loss': 0.15992265263685404}

# %% [markdown]
# **Classification Report**

# %%
from sklearn.metrics import classification_report

def class_report(labels, preds):
      return classification_report(labels, preds, average='micro')


class_report, model_outputs, wrong_predictions = model.eval_model(test_df, report = classification_report)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# ...
# Running Evaluation:   0%|          | 0/250 [00:00<?, ?it/s]

# %%
class_report
# Out:
# {'mcc': 0.9461412062128047,
# ...

# %% [markdown]
# **Predicting Dialouges**

# %%
prediction, output = model.predict(['Play starwars'])
# Out:
# ...
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
prediction = le.inverse_transform(prediction)
prediction
# Out:
# array(['__label__games'], dtype=object)

# %% [markdown]
# # In conlcusion, fine tuning the RoBerta model achieved the folowing results
# **Final Accuracy = 95%**
#
# **Final F1 Score = 95%**
